# %%
import tensorflow as tf
x = tf.constant([35, 40, 45], name='x')
y = tf.Variable(x + 5, name='y')

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    print(sess.run(y))
# Out:
# [40 45 50]

# %%
import numpy as np

# %%
data = np.random.randint(1000, size=10000)

# %%
data
# Out:
# array([626, 433, 821, ..., 167, 791, 501])

# %%
x = tf.constant(np.random.randint(1000), name='x')
#print(x)
y = tf.Variable(x, name='y')

with tf.Session() as sess:
    merged = tf.summary.merge_all()
    writer = tf.summary.FileWriter('basic', sess.graph)
    init = tf.global_variables_initializer()
    sess.run(init)
    print(sess.run(x))
    for i in range(5):
        new = np.random.randint(1000)
        print(new)
        y = (y + new)/2
        print(sess.run(y))
# Out:
# 853
# 432
# 642.5
# 757
# 699.75
# 85
# 392.375
# 0
# 196.1875
# 217
# 206.59375

# %%
import matplotlib.image as mpimg

# %%
filename = 'MarshOrchid.jpg'

# %%
image = mpimg.imread(filename)

# %%
image.shape
# Out:
# (5528, 3685, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()

# %%
x = tf.Variable(image, name='x')
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess: 
    sess.run(init)
    print(sess.run(x).shape)
    print("############")
    x = tf.transpose(x, perm=[1, 0, 2])
    plt.imshow(sess.run(x))
    plt.show()
    
#plt.imshow(result)
#plt.show()
# Out:
# (5528, 3685, 3)
# ############

# %%
x = tf.placeholder("float", None)
y = x * 2
with tf.Session() as sess:
    result = sess.run(y, feed_dict={x: [1, 2, 3]})
    print(result)
# Out:
# [2. 4. 6.]

# %%
import resource
print("{} Kb".format(resource.getrusage(resource.RUSAGE_SELF).ru_maxrss))
# Out:
# 1552670720 Kb
